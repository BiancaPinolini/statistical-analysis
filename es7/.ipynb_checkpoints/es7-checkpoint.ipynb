# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
mu_s = [0,0]
cov_s = [[0.09, 0.045], [0.045, 0.09]]

# %%
mu_b = [4,4]
cov_b = [[1., 0.4], [0.4, 1.]]

# %%
x_s, y_s = np.random.multivariate_normal(mu_s, cov_s, 50000).T
x_b, y_b = np.random.multivariate_normal(mu_b, cov_b, 50000).T

# %%
plt.figure(figsize=(7, 7))
plt.plot(x_s, y_s, '.', color = 'red', label = 'signal')
plt.plot(x_b, y_b, '.', color = 'blue', label = 'background')
plt.legend()
plt.show()

# %% [markdown]
# plt.hist(x_s, bins=200, color = 'red', histtype = 'step', label = 'signal')
# plt.hist(x_b, bins=200, color = 'blue', histtype = 'step', label = 'background')
# plt.xlabel('X')
# plt.legend()
# plt.show()

# %% [markdown]
# plt.hist(y_s, bins=200, color = 'red', histtype = 'step', label = 'signal')
# plt.hist(y_b, bins=200, color = 'blue', histtype = 'step', label = 'background')
# plt.xlabel('Y')
# plt.legend()
# plt.show()

# %%
x = np.append(x_s,x_b)
y = np.append(y_s,y_b)

# %%
s_b = np.array([])

for i in range (50000):
    s_b = np.append(s_b,1)
    
for i in range (50000):
    s_b = np.append(s_b,0)

# %%
data = pd.DataFrame(
    {
        'x': x,
        'y': y,
        's_b': s_b
    }
)

# %%
data.head()
# Out:
#           x         y  s_b
# 0  0.137246 -0.238643  1.0
# 1 -0.473423  0.026301  1.0
# 2  0.077839  0.089250  1.0
# 3 -0.142031  0.137472  1.0
# 4  0.283424 -0.043741  1.0

# %%
X = data[['x', 'y']]
y = data['s_b']

# %% [markdown]
# ## Classificazione

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.metrics import log_loss

# %%
# 
classes = data["s_b"].unique()
classes

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, y, test_size=0.3)

# %%
le = LabelEncoder()
Y_train = le.fit_transform(Y_train)
Y_test = le.transform(Y_test)
np.unique(Y_test)
# Out:
# array([0, 1])

# %%
ss = StandardScaler()
X_train = ss.fit_transform(X_train)
X_test = ss.transform(X_test)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

lr = LogisticRegression(solver='lbfgs')
lr.fit(X_train, Y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
Y_pred = lr.predict(X_test)
Y_pred_proba = lr.predict_proba(X_test)
A = accuracy_score(Y_test, Y_pred)
LL = log_loss(Y_test, Y_pred_proba)
print('ACCURACY = ', round(A,2))
print('LOG LOSS = ', round(LL,2))
# Out:
# ACCURACY =  1.0
# LOG LOSS =  0.0

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(Y_test, Y_pred)
cm
# Out:
# array([[14964,     6],
#        [    0, 15030]])

# %%
# Out:
# array([1., 0.])

# %%
fig, ax = plt.subplots()
im = ax.imshow(cm, cmap=plt.cm.Blues)

ax.figure.colorbar(im, ax=ax)
ax.set(xticks=np.arange(cm.shape[1]),
       yticks=np.arange(cm.shape[0]),
       xticklabels=classes,
       yticklabels=classes,
       ylabel='True label',
       xlabel='Predicted label')

# Loop over data dimensions and create text annotations.
for i in range(cm.shape[0]):
    for j in range(cm.shape[1]):
        ax.text(j, i, format(cm[i, j], 'd'),
                ha="center", va="center",
                color="white" if cm[i, j] > cm.max() / 2. else "black")
        
fig.tight_layout()

# %%
X_all = data[['x', 'y']].values
X_all = ss.transform(X_all)

prev_value = lr.predict(X_all)
prev_value = le.inverse_transform(prev_value)

data['s_b'] = prev_value
