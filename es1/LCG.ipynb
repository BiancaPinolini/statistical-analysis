# %% [markdown]
# ## LCG algorithm

# %%
# we insert the seed
seed = '1'
# we then insert the three parameters
m = 2**32
a = 1103515245
c = 12345

# we introduce some variables useful for the code
number = int(seed);
PR_list = []
counter = 0

# we implement the LCG method loop
while number not in PR_list:
    # we want to generate 3*10^5 numbers
    if counter > 5000:
        break;
    counter += 1
    # we add the number to the pseudo-random generated list
    PR_list.append(number)
    # we calculate the next number
    number = (a * number + c) % m

# %% [markdown]
# We write the LCG-generate numbers in a file called list_num

# %%
with open('list_num', 'w') as f:
    for item in PR_list:
        f.write("%s\n" % item)

# %% [markdown]
# We then convert the list in an array of integers

# %%
import numpy as np
myarray = np.asarray(PR_list)

# %%
lista = myarray.astype(np.int)

# %% [markdown]
# Finally we plot the numbers in a 3D space as space coordinates and in a histogram to see whether they are uniformly distributed

# %%
list1 = lista[:1000]
list2 = lista[1000:2000]
list3 = lista[2000:3000]

# %%
import matplotlib.pyplot as plt

plt.hist(lista, bins = 80, color='blue', histtype='step')
plt.ylim(0,100)
plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D 

fig = plt.figure(figsize=(7, 7))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(list1, list2, list3, marker='o', color='red')
